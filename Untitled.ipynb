// %%
var latestAscents = { ascents: 
   [ { ascentId: 0,
       areaName: 'Boulder/CO',
       areaSlug: 'boulder-co',
       cragName: 'Easter Rock',
       cragSlug: 'easter-rock',
       sectorSlug: 'unknown-sector',
       zlaggableName: 'Catwoman',
       zlaggableSlug: 'catwoman',
       countrySlug: 'united-states',
       userAvatar: 'gallery/58414.jpg',
       userName: 'Mason Caiby',
       userSlug: 'mason-caiby',
       date: '2020-06-04T00:00:00+00:00',
       difficulty: '7b',
       gradeIndex: 25,
       comment: 'Heard she gets 13a now. Maybe a flake broke? Hard sayin. Bit go-ey at the bottom. Cool little riggy. despite the 1.5 stars on MP, i think this deserves a recommendation. 2nd go? Idk how to count them when you fall off the first move on the first go and end up on the ground. Also, some sort of penis joke to appease my fans.',
       isHard: false,
       isEasy: false,
       firstAscent: false,
       secondGo: true,
       type: 'rp',
       notes: 'Heard she gets 13a now. Maybe a flake broke? Hard sayin. Bit go-ey at the bottom. Cool little riggy. despite the 1.5 stars on MP, i think this deserves a recommendation. 2nd go? Idk how to count them when you fall off the first move on the first go and end up on the ground. Also, some sort of penis joke to appease my fans.',
       rating: 3 },
     { ascentId: 0,
       areaName: 'Boulder/CO',
       areaSlug: 'boulder-co',
       cragName: 'Easter Rock',
       cragSlug: 'easter-rock',
       sectorSlug: 'unknown-sector',
       zlaggableName: 'Flying Beast',
       zlaggableSlug: 'flying-beast',
       countrySlug: 'united-states',
       userAvatar: 'gallery/58414.jpg',
       userName: 'Mason Caiby',
       userSlug: 'mason-caiby',
       date: '2020-06-03T00:00:00+00:00',
       difficulty: '7b',
       gradeIndex: 25,
       comment: 'Hadn\'t ever done this one. Now I have. Felt hard, no knee-bar just jumped to holds and shoved my hand in a crack. Tried it once years ago. Fun day with DLEE. ',
       isHard: false,
       isEasy: false,
       firstAscent: false,
       secondGo: false,
       type: 'rp',
       notes: 'Hadn\'t ever done this one. Now I have. Felt hard, no knee-bar just jumped to holds and shoved my hand in a crack. Tried it once years ago. Fun day with DLEE. ',
       rating: 3 },
     { ascentId: 0,
       areaName: null,
       areaSlug: null,
       cragName: 'Flatirons',
       cragSlug: 'flatirons',
       sectorSlug: 'seal-rock',
       zlaggableName: 'The Hinge',
       zlaggableSlug: 'the-hinge',
       countrySlug: 'united-states',
       userAvatar: 'gallery/58414.jpg',
       userName: 'Mason Caiby',
       userSlug: 'mason-caiby',
       date: '2020-05-27T00:00:00+00:00',
       difficulty: '7b',
       gradeIndex: 25,
       comment: 'Hard one for me. Most of the A grade take me a day and 1-3 goes. This one took 2 days and 5 goes. Might be the \'rona; hard sayin. Dont remember the last time i climbed a &gt;= 4a in a pair of shorts. Hot swampy times call for desperate measures.\n<br>\nExcellent pitch of power slab. I missed rock climbing with my friends.',
       isHard: false,
       isEasy: false,
       firstAscent: false,
       secondGo: false,
       type: 'rp',
       notes: 'Hard one for me. Most of the A grade take me a day and 1-3 goes. This one took 2 days and 5 goes. Might be the \'rona; hard sayin. Dont remember the last time i climbed a &gt;= 4a in a pair of shorts. Hot swampy times call for desperate measures.\n<br>\nExcellent pitch of power slab. I missed rock climbing with my friends.',
       rating: 4 },
     { ascentId: 0,
       areaName: 'Boulder/CO',
       areaSlug: 'boulder-co',
       cragName: 'Easter Rock',
       cragSlug: 'easter-rock',
       sectorSlug: 'unknown-sector',
       zlaggableName: 'Empire of the Fenceless',
       zlaggableSlug: 'empire-of-the-fenceless',
       countrySlug: 'united-states',
       userAvatar: 'gallery/58414.jpg',
       userName: 'Mason Caiby',
       userSlug: 'mason-caiby',
       date: '2020-06-03T00:00:00+00:00',
       difficulty: '6c',
       gradeIndex: 21,
       comment: 'Repeat yesterday',
       isHard: false,
       isEasy: false,
       firstAscent: false,
       secondGo: false,
       type: 'rp',
       notes: 'Repeat yesterday',
       rating: 0 },
    ]}

// %%
latestAscents = latestAscents["ascents"];
// Out:
// [
//   {
//     ascentId: 0,
//     areaName: 'Boulder/CO',
//     areaSlug: 'boulder-co',
//     cragName: 'Easter Rock',
//     cragSlug: 'easter-rock',
//     sectorSlug: 'unknown-sector',
//     zlaggableName: 'Catwoman',
//     zlaggableSlug: 'catwoman',
//     countrySlug: 'united-states',
//     userAvatar: 'gallery/58414.jpg',
//     userName: 'Mason Caiby',
//     userSlug: 'mason-caiby',
//     date: '2020-06-04T00:00:00+00:00',
//     difficulty: '7b',
//     gradeIndex: 25,
//     comment: 'Heard she gets 13a now. Maybe a flake broke? Hard sayin. Bit go-ey at the bottom. Cool little riggy. despite the 1.5 stars on MP, i think this deserves a recommendation. 2nd go? Idk how to count them when you fall off the first move on the first go and end up on the ground. Also, some sort of penis joke to appease my fans.',
//     isHard: false,
//     isEasy: false,
//     firstAscent: false,
//     secondGo: true,
//     type: 'rp',
// ...

// %%
const myAscents = latestAscents.sort((a, b) => {
    a = Date.parse(a.date);
    b = Date.parse(b.date);
    return a>b ? -1 : a<b ? 1 : 0;
})

// %%
myAscents
// Out:
// [
//   {
//     ascentId: 0,
//     areaName: 'Boulder/CO',
//     areaSlug: 'boulder-co',
//     cragName: 'Easter Rock',
//     cragSlug: 'easter-rock',
//     sectorSlug: 'unknown-sector',
//     zlaggableName: 'Catwoman',
//     zlaggableSlug: 'catwoman',
//     countrySlug: 'united-states',
//     userAvatar: 'gallery/58414.jpg',
//     userName: 'Mason Caiby',
//     userSlug: 'mason-caiby',
//     date: '2020-06-04T00:00:00+00:00',
//     difficulty: '7b',
//     gradeIndex: 25,
//     comment: 'Heard she gets 13a now. Maybe a flake broke? Hard sayin. Bit go-ey at the bottom. Cool little riggy. despite the 1.5 stars on MP, i think this deserves a recommendation. 2nd go? Idk how to count them when you fall off the first move on the first go and end up on the ground. Also, some sort of penis joke to appease my fans.',
//     isHard: false,
//     isEasy: false,
//     firstAscent: false,
//     secondGo: true,
//     type: 'rp',
// ...

// %%
latestAscents["ascents"].forEach((Lsend) => {
    var msg = `User: ${Lsend.userName}
Route: ${Lsend.zlaggableName}
Crag: ${Lsend.cragName}
Area: ${Lsend.areaName}
Difficulty: ${Lsend.difficulty}
`
    console.log(msg)
})
// Out:
// User: Mason Caiby
// Route: Catwoman
// Crag: Easter Rock
// Area: Boulder/CO
// Difficulty: 7b
//
// User: Mason Caiby
// Route: Flying Beast
// Crag: Easter Rock
// Area: Boulder/CO
// Difficulty: 7b
//
// User: Mason Caiby
// Route: The Hinge
// Crag: Flatirons
// Area: null
// Difficulty: 7b
//
// User: Mason Caiby
// Route: Empire of the Fenceless
// Crag: Easter Rock
// Area: Boulder/CO
// Difficulty: 6c
